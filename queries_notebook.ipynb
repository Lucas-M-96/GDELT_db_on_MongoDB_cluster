# %%
import pymongo
import datetime
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
# dans le string on peut passer les contraintes sur R et W
conn_str = "mongodb://localhost:27017/"
try:
    mongo_client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)
    print("Pymongo : connection OK")
    db = mongo_client.gdelt
    coll = db.evt
except Exception:
    print("Pymongo : unable to connect to the server.")
# Out:
# Pymongo : connection OK

# %%
count = coll.estimated_document_count()
print(f"total number of documents in the collection : {count}")
# Out:
# total number of documents in the collection : 39385845

# %% [markdown]
# ## **Requête 1**

# %%
day = datetime.datetime(2021,4,14)
country = "US"
lang = "eng"
limit_total_events = 10000

start = datetime.datetime.now()

cursor = coll.aggregate([
    {"$match": {"$and": [{"date":day},{"country":country}]}},
    {"$project": {"_id":0,"ID":1, "list_articles":1,"num_mentions":1}},
    {"$unwind": "$list_articles"},
    {"$match": {"list_articles.lang": lang}},
    {"$group": {"_id":[{"event":"$ID"}, {"num_mentions":"$num_mentions"}],"nb_articles":{"$count":{}}}},
    {"$sort": {"nb_articles":-1}}
    ,{"$limit": limit_total_events}
])

duration1 = datetime.datetime.now() - start
print(f"query processed in {duration1}")

start = datetime.datetime.now()
df_res = pd.DataFrame(list(cursor))

new_col = ["event", "num_mentions"]

for i, col in enumerate(new_col):
    df_res.insert(i+1, col, df_res.loc[:, '_id'].apply(pd.Series)[i])
    df_res.loc[:, col] = df_res.loc[:, col].apply(lambda x : x.get(col))
    
df_res = df_res.drop('_id', axis=1)
    
# df_res.loc[:, "_id"] = df_res.loc[:, "_id"].apply(lambda x : re.search("\d+", str(x)).group(0))

df_res = df_res.set_index("event")
duration2 = datetime.datetime.now() - start

print(f"results gathered in dataframe in {duration2}")

print(f"total time : {duration1 + duration2}")
df_res
# Out:
# query processed in 0:00:01.175777
# results gathered in dataframe in 0:00:03.337802
# total time : 0:00:04.513579
#            num_mentions  nb_articles
# event
# 979650993            40          671
# 979651141             8          610
# 979651126            52          553
# 979651319            29          543
# 979650996             2          446
# ...                 ...          ...
# 979672680             2            2
# 979721040             3            2
# 979686092             2            2
# 979763483            12            2
# 979660816             8            2
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## **Requête 2**

# %%
country="IT"
granularity="m"
mentions_treshold = 20  # US : 100, autre : 20
limit_events_per_granularity = 35

# VERSION MONGO-PANDAS
start = datetime.datetime.now()
cursor = coll.aggregate([
    {"$match": {"$and": [{"country":country},{"num_mentions":{"$gt":mentions_treshold}}]}}, # AVEC TRESHOLD
    {"$project": {"_id":0,
                  "ID":1,
                  "time":"$date",
                  "num_mentions":1}},
                  # un limit global n'a pas de sens ici car données non triées
])

duration1 = datetime.datetime.now() - start
print(f"query processed in {duration1}")

start = datetime.datetime.now()
df_res = pd.DataFrame(list(cursor))
print(f"number of events returned before post-processing : {len(df_res)}")
if granularity == 'd':
    strf='%Y/%m/%d'
elif granularity == 'm':
    strf='%Y/%m'
else:
    strf='%Y'
df_res["time"] = pd.to_datetime(df_res["time"]).dt.strftime(strf)
df_res = df_res.sort_values(['time','num_mentions'],ascending=[True,False])
df_res = df_res.set_index('time')
df_res = df_res.groupby(df_res.index).head(limit_events_per_granularity)
duration2 = datetime.datetime.now() - start

print(f"results gathered in dataframe in {duration2}")

print(f"total time : {duration1 + duration2}")
df_res
# Out:
# query processed in 0:00:01.093995
# number of events returned before post-processing : 3582
# results gathered in dataframe in 0:00:02.984223
# total time : 0:00:04.078218
#                 ID  num_mentions
# time
# 2021/01  964967428           130
# 2021/01  962761536           122
# 2021/01  963167892           110
# 2021/01  966336634            85
# 2021/01  963442704            80
# ...            ...           ...
# 2021/08  998618196            50
# 2021/08  999147756            50
# 2021/08  999415375            50
# 2021/08  999487169            50
# 2021/08  999495361            50
#
# [280 rows x 2 columns]

# %% [markdown]
# ## **Requête 3**

# %%
source="lorrain"
granularity="m" #d/m/y",
var="persons" #"theme", "locs", "persons"
limit_total_responses = 500

dico_rq3 = {"$group": {"_id": [{"source":"$list_articles.source"}, 
                               {"$cond": [var=="theme", 
                                          {f"{var}":f"${var}_base"}, 
                                          {f"{var}":f"$list_articles.{var}"}]}, 
                               {"time":{"$cond": [granularity=='d', {"$concat":[{"$toString":{"$year":"$date"}}, 
                                                                                '/', 
                                                                                {"$toString":{"$month":"$date"}},
                                                                                '/', 
                                                                                {"$toString":{"$dayOfMonth":"$date"}}]}, 
                                                  {"$cond": [granularity=='m', 
                                                             {"$concat":[{"$toString":{"$year":"$date"}},    
                                                                         '/', 
                                                                         {"$toString":{"$month":"$date"}}]}, 
                                                             {"$toString":{"$year":"$date"}}]}]}}], 
                       "nb_articles": {"$count":{}}, 
                       "avg_tone": {"$avg":{"$toDouble":"$list_articles.tone"}}}}

start = datetime.datetime.now()

if var=='theme':
    cursor = coll.aggregate([
        {"$match": {"list_articles.source":{"$regex":source}}},
        {"$unwind":"$list_articles"},
        {"$match": {"list_articles.source":{"$regex":source}}},
        dico_rq3,
        {"$sort": {"nb_articles":-1, "time":1}},
        {"$limit": limit_total_responses}
    ])
    
else:
     cursor = coll.aggregate([
        {"$match": {"list_articles.source":{"$regex":source}}},
        {"$unwind":"$list_articles"},
        {"$match": {"list_articles.source":{"$regex":source}}},
        {"$unwind": f"$list_articles.{var}"},
        dico_rq3,
        {"$sort": {"nb_articles":-1, "time":1}},
        {"$limit": limit_total_responses}
    ])
    

# print_find(cursor)

duration1 = datetime.datetime.now() - start
print(f"query processed in {duration1}")

start = datetime.datetime.now()
df_res = pd.DataFrame(list(cursor))


new_col = ["source", var, "time"]
#transforme une colonne pandas composée d'une liste de dictionnaires en plusieurs colonnes
for i, col in enumerate(new_col):
    df_res.insert(i+1, col, df_res.loc[:, '_id'].apply(pd.Series)[i])
    df_res.loc[:, col] = df_res.loc[:, col].apply(lambda x : x.get(col))
    
df_res = df_res.drop('_id', axis=1)
#df_test.loc[:, 'time'] = pd.to_datetime(df_test.loc[:, 'time'], format='%Y/%m').dt.month
duration2 = datetime.datetime.now() - start

print(f"results gathered in dataframe in {duration2}")

print(f"total time : {duration1 + duration2}")
df_res
# Out:
# query processed in 0:06:30.721752
# results gathered in dataframe in 0:00:00.246538
# total time : 0:06:30.968290
#                      source                persons    time  nb_articles  \
# 0    republicain-lorrain.fr              joe biden  2021/8          229
# 1    republicain-lorrain.fr              joe biden  2021/1          131
# 2    republicain-lorrain.fr              gaza gaza  2021/5          119
# 3    republicain-lorrain.fr           donald trump  2021/1          100
# 4    republicain-lorrain.fr              joe biden  2021/5           89
# ..                      ...                    ...     ...          ...
# 495  republicain-lorrain.fr            john mcafee  2021/6            8
# 496  republicain-lorrain.fr        francis szpiner  2021/4            8
# 497  republicain-lorrain.fr  jean-baptiste lemoyne  2021/6            8
# 498  republicain-lorrain.fr           adam hussein  2021/1            8
# 499  republicain-lorrain.fr            jules favre  2021/1            8
#
#      avg_tone
# 0   -3.357471
# 1   -2.339645
# 2   -4.692661
# 3   -2.776858
# 4   -2.971837
# ..        ...
# 495 -3.084833
# 496 -6.783370
# 497 -1.050788
# 498 -8.490566
# 499  0.000000
#
# [500 rows x 5 columns]

# %% [markdown]
# ## **Requête 4**

# %%
def bloc_match_1(month_start,next_month_start):
    # util function used in all queries
    dico_bloc_match_1 = {"$and":[
        {"$or":[
            {"$and": [{"act1_country":pays_1}, {"act2_country":pays_2}]},
            {"$and": [{"act1_country":pays_2}, {"act2_country":pays_1}]}]},
        {"$and":[{"date": {"$gte":month_start}},{"date": {"$lt":next_month_start}}]}
        ]}
    return dico_bloc_match_1


def process_all_queries(date_range):
    # processes all queries (tone,articles,events,events_code, localisations, persons, sources) and return a list of dfs (one per month in daterange)
    
    queries_start = datetime.datetime.now()
    
    list_monthly_dfs = [pd.DataFrame() for i in range(len(date_range)-1)]
    for i in range(len(date_range)-1):
        month_start = date_range[i]
        next_month_start = date_range[i+1]

        start = datetime.datetime.now()
        # nb d'events
        nb_events = coll.count_documents(bloc_match_1(month_start,next_month_start))
        # nb d'articles
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$unwind":"$list_articles"},
            {"$count":"nb_articles"}
        ])
        nb_articles = list(cursor)[0]['nb_articles']
        # ton moyen
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$group":{"_id":"_id","avg_evt_tone":{'$avg':"$tone"}}}
        ])
        avg_tone = list(cursor)[0]['avg_evt_tone']
        # regroupement    
        _id = ["nb_events","nb_articles","avg_tone"]
        val = [nb_events,nb_articles,avg_tone]
        df_scalar = pd.DataFrame(zip(_id,val))
        df_scalar = df_scalar.set_axis(["_id","val"],axis=1)
        duration1 = datetime.datetime.now() - start
        print(f"{month_start.strftime('%Y-%m')} : scalar queries processed in {duration1}")

        # most common event_codes - exprimé en nombre d'events par type
        start = datetime.datetime.now()
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$group":{"_id":"$theme_base","val":{'$count':{}}}},
            {"$sort": {"val":-1}},
            {"$limit":n_limit}
        ])
        df_res_evt_code = pd.DataFrame(list(cursor))
        duration1 = datetime.datetime.now() - start
        print(f"{month_start.strftime('%Y-%m')} : event type query processed in {duration1}")



        # top 3 people - exprimé en nombre d'articles citant chaque personne
        start = datetime.datetime.now()
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$unwind":"$list_articles"},
            {"$unwind":"$list_articles.persons"},
            {"$group": {"_id": "$list_articles.persons","val":{"$count":{}}}},
            {"$sort": {"val":-1}},
            {"$limit":n_limit}
        ])
        df_res_pers = pd.DataFrame(list(cursor))
        duration1 = datetime.datetime.now() - start
        print(f"{month_start.strftime('%Y-%m')} : persons query processed in {duration1}")
        
        
        # top 3 organizations
        start = datetime.datetime.now()
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$unwind":"$list_articles"},
            {"$unwind":"$list_articles.org"},
            {"$group": {"_id": "$list_articles.org","val":{"$count":{}}}},
            {"$sort": {"val":-1}},
            {"$limit":n_limit}
        ])
        df_res_orgs = pd.DataFrame(list(cursor))
        duration1 = datetime.datetime.now() - start
        print(f"{month_start.strftime('%Y-%m')} : organizations query processed in {duration1}")


        # top 3 locations
        start = datetime.datetime.now()
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$unwind":"$list_articles"},
            {"$unwind":"$list_articles.locs"},
            {"$group": {"_id": "$list_articles.locs","val":{"$count":{}}}},
            {"$sort": {"val":-1}},
            {"$limit": n_limit}
        ])
        df_res_locs = pd.DataFrame(list(cursor))
        duration1 = datetime.datetime.now() - start
        print(f"{month_start.strftime('%Y-%m')} : locations query processed in {duration1}")


        # top 3 sources
        start = datetime.datetime.now()
        cursor = coll.aggregate([
            {"$match" : bloc_match_1(month_start,next_month_start)},
            {"$unwind":"$list_articles"},
            {"$group": {"_id": "$list_articles.source","val":{"$count":{}}}},
            {"$sort": {"val":-1}},
            {"$limit":n_limit}
        ])
        df_res_src = pd.DataFrame(list(cursor))
        duration1 = datetime.datetime.now() - start
        print(f"{month_start.strftime('%Y-%m')} : sources query processed in {duration1}")

        # vertical concatenation of all sub_df of the current month
        list_sub_df_per_month = [df_scalar,df_res_evt_code,df_res_pers,df_res_orgs,df_res_locs,df_res_src]
        for df in list_sub_df_per_month:
            list_monthly_dfs[i] = pd.concat([list_monthly_dfs[i],df],axis=0)

        # --Indexation of monthly df
        # index length will be < than (3 + 5 * n_limit) if not enough rows matching some requests
        index = ["nb_events","nb_articles","avg_tone"]
        index.extend([f"event_type_{i}" for i in range(len(df_res_evt_code))])
        index.extend([f"person_{i}" for i in range(len(df_res_pers))])
        index.extend([f"org_{i}" for i in range(len(df_res_orgs))])
        index.extend([f"locs_{i}" for i in range(len(df_res_locs))])
        index.extend([f"source_{i}" for i in range(len(df_res_src))])
        list_monthly_dfs[i] = list_monthly_dfs[i].set_axis(index,axis=0)
        list_monthly_dfs[i]["val"] = list_monthly_dfs[i]["val"].round(1)

    queries_duration = datetime.datetime.now() - queries_start
    print(f"Total query time : {queries_duration}")
    return list_monthly_dfs

def generate_global_df(list_monthly_dfs):
    # gathers a list of monthly dataframes into a global readable dataframe

    global_df = pd.DataFrame()

    # reindexation de tous les dataframes à la taille théorique (utile dans le cas où il y aurait trop peu de valeurs retournées sur certaines dates)
    index = ["nb_events","nb_articles","avg_tone"]
    index.extend([f"event_type_{i}" for i in range(n_limit)])
    index.extend([f"person_{i}" for i in range(n_limit)])
    index.extend([f"org_{i}" for i in range(n_limit)])
    index.extend([f"locs_{i}" for i in range(n_limit)])
    index.extend([f"source_{i}" for i in range(n_limit)])

    # concatenation horizontale des dataframes asociés à chaque mois
    for df in list_monthly_dfs:
        df = df.reindex(index)
        global_df = pd.concat([global_df,df],axis=1)

    # renommage des colonnes en fonction du mois auquel elles correspondent
    columns = []
    for date in date_range[:-1]:
        columns.extend([f"{date.strftime('%Y-%m')}_id",f"{date.strftime('%Y-%m')}_val"])
    global_df = global_df.set_axis(columns,axis=1)
    
    return global_df


def display_evolution(global_df):
    # display evolution of nb articles, events and tone over the month of the analysis

    nb_events_evol = global_df.loc["nb_events",:].iloc[1::2].astype(float)
    nb_articles_evol = global_df.loc["nb_articles",:].iloc[1::2].astype(float)
    avg_tone_evol = global_df.loc["avg_tone",:].iloc[1::2].astype(float)

    fig = plt.figure(figsize=[10,8])
    axes = fig.subplots(2,1)
    axes[0].plot(nb_events_evol,'o-',label="nb events")
    axes[0].plot(nb_articles_evol,'o-',label="nb articles")
    axes[0].set_ylim([0,max(nb_articles_evol)+10])
    axes[0].set_title("Evolution du nombre d'events et d'articles au cours du temps")
    axes[0].legend()
    axes[1].plot(avg_tone_evol,'o-',label="avg_tone",c="k")
    axes[1].set_ylim([-10,10])
    axes[1].set_title("Evolution de l'average tone au cours du temps")
    axes[1].legend()

# %%
date_min = 20210101 # indiquer le 1er jour du premier mois à analyser - format YYYYMMDD
date_max = 20210901 # indiquer le 1er du mois suivant le dernier mois à analyser (ie si je veux analyser le mois d'avril, je mets 20210105)

pays_1 = "IT"
pays_2 = "KN"
n_limit = 5

global_start = datetime.datetime.now()

# generation manuelle de la date_range
date_min = pd.to_datetime(str(date_min))
date_max = pd.to_datetime(str(date_max))
date_range = pd.date_range(date_min,date_max,freq="MS")

# appel des fonctions
list_monthly_dfs = process_all_queries(date_range)
global_df = generate_global_df(list_monthly_dfs)
print(global_df)
display_evolution(global_df)

global_duration = datetime.datetime.now() - global_start
print(f"\n\nTOTAL TIME : {global_duration}\n\n")
# Out:
# 2021-01 : scalar queries processed in 0:00:00.223291
# 2021-01 : event type query processed in 0:00:00.009777
# 2021-01 : persons query processed in 0:00:00.006578
# 2021-01 : organizations query processed in 0:00:00.006231
# 2021-01 : locations query processed in 0:00:00.005820
# 2021-01 : sources query processed in 0:00:00.005967
# 2021-02 : scalar queries processed in 0:00:00.168165
# 2021-02 : event type query processed in 0:00:00.013462
# 2021-02 : persons query processed in 0:00:00.004387
# 2021-02 : organizations query processed in 0:00:00.004385
# 2021-02 : locations query processed in 0:00:00.004200
# 2021-02 : sources query processed in 0:00:00.003950
# 2021-03 : scalar queries processed in 0:00:00.127790
# 2021-03 : event type query processed in 0:00:00.096419
# 2021-03 : persons query processed in 0:00:00.005144
# 2021-03 : organizations query processed in 0:00:00.007756
# 2021-03 : locations query processed in 0:00:00.005214
# 2021-03 : sources query processed in 0:00:00.004394
# 2021-04 : scalar queries processed in 0:00:00.066986
# 2021-04 : event type query processed in 0:00:00.004793
# 2021-04 : persons query processed in 0:00:00.004493
# 2021-04 : organizations query processed in 0:00:00.004289
# 2021-04 : locations query processed in 0:00:00.004606
# 2021-04 : sources query processed in 0:00:00.004520
# 2021-05 : scalar queries processed in 0:00:00.043416
# 2021-05 : event type query processed in 0:00:00.004273
# 2021-05 : persons query processed in 0:00:00.004340
# 2021-05 : organizations query processed in 0:00:00.004809
# 2021-05 : locations query processed in 0:00:00.004480
# 2021-05 : sources query processed in 0:00:00.004468
# 2021-06 : scalar queries processed in 0:00:00.047568
# 2021-06 : event type query processed in 0:00:00.004079
# 2021-06 : persons query processed in 0:00:00.003737
# 2021-06 : organizations query processed in 0:00:00.003606
# 2021-06 : locations query processed in 0:00:00.003564
# 2021-06 : sources query processed in 0:00:00.003691
# 2021-07 : scalar queries processed in 0:00:00.036157
# 2021-07 : event type query processed in 0:00:00.004603
# 2021-07 : persons query processed in 0:00:00.004076
# 2021-07 : organizations query processed in 0:00:00.004008
# 2021-07 : locations query processed in 0:00:00.004024
# 2021-07 : sources query processed in 0:00:00.004175
# 2021-08 : scalar queries processed in 0:00:00.023544
# 2021-08 : event type query processed in 0:00:00.004644
# 2021-08 : persons query processed in 0:00:00.004378
# 2021-08 : organizations query processed in 0:00:00.004052
# 2021-08 : locations query processed in 0:00:00.004308
# 2021-08 : sources query processed in 0:00:00.004259
# Total query time : 0:00:01.075899
#                                  2021-01_id  2021-01_val  \
# nb_events                         nb_events         12.0
# nb_articles                     nb_articles         66.0
# avg_tone                           avg_tone         -1.3
# event_type_0                         Yield           7.0
# event_type_1                         Reject          2.0
# event_type_2                   Make a visit          1.0
# event_type_3                         Demand          1.0
# event_type_4                   Host a visit          1.0
# person_0                      kim byung-kee         40.0
# person_1                       jon gambrell         21.0
# person_2                          chang sik         19.0
# person_3                      shin beomchul         14.0
# person_4                          joe biden         11.0
# org_0         national intelligence service         57.0
# org_1                          worker party         57.0
# org_2                        united nations         44.0
# org_3                        korean embassy         43.0
# org_4                      associated press         41.0
# locs_0                                   IT         66.0
# locs_1                                   KN         66.0
# locs_2                                   KS         64.0
# locs_3                                   KU         63.0
# locs_4                                   UK         61.0
# source_0                        reuters.com          6.0
# source_1                        asiaone.com          3.0
# source_2                            msn.com          2.0
# source_3                         apnews.com          2.0
# source_4                         tucson.com          1.0
#
#                                             2021-02_id  2021-02_val  \
# nb_events                                    nb_events         19.0
# nb_articles                                nb_articles         21.0
# avg_tone                                      avg_tone         -0.6
# event_type_0                                   Consult         10.0
# event_type_1                              Make a visit          3.0
# event_type_2                            Make statement          2.0
# event_type_3                                    Yield           2.0
# event_type_4           Impose administrative sanctions          1.0
# person_0                                  pope francis         11.0
# person_1                                     joe biden          9.0
# person_2                             marco impagliazzo          9.0
# person_3                                  kim yong nam          9.0
# person_4                                  donald trump          6.0
# org_0                          community of santegidio         11.0
# org_1         presidium of the supreme people assembly          9.0
# org_2                                              cnn          5.0
# org_3                                u s supreme court          2.0
# org_4                              european commission          2.0
# locs_0                                              KN         21.0
# locs_1                                              IT         21.0
# locs_2                                              KS         16.0
# locs_3                                              VM         11.0
# locs_4                                              VT          9.0
# source_0                                       upi.com          9.0
# source_1                              koreatimes.co.kr          4.0
# source_2                                       msn.com          3.0
# source_3                                 oc-breeze.com          2.0
# source_4                               koreaherald.com          1.0
#
#                                     2021-03_id  2021-03_val  \
# nb_events                            nb_events          4.0
# nb_articles                        nb_articles          5.0
# avg_tone                              avg_tone         -2.2
# event_type_0  Abduct, hijack, or take hostage           2.0
# event_type_1    Engage in material cooperation          1.0
# event_type_2   Use conventional military force          1.0
# event_type_3                               NaN          NaN
# event_type_4                               NaN          NaN
# person_0                          leigh scheps          2.0
# person_1                          mario draghi          2.0
# person_2                        suga yoshihide          2.0
# person_3                        richard iacona          1.0
# person_4                                   NaN          NaN
# org_0               army corporal david milano          2.0
# org_1           attorney or of police judicial          1.0
# org_2                        court the freedom          1.0
# org_3                          office of power          1.0
# org_4             union rooms criminal italian          1.0
# locs_0                                      KN          5.0
# locs_1                                      IT          5.0
# locs_2                                      HK          2.0
# locs_3                                      JA          2.0
# locs_4                                      CH          2.0
# source_0                               msn.com          2.0
# source_1                             nhk.or.jp          2.0
# source_2                  ilfattoquotidiano.it          1.0
# source_3                                   NaN          NaN
# source_4                                   NaN          NaN
#
#                                             2021-04_id  2021-04_val  \
# nb_events                                    nb_events          8.0
# nb_articles                                nb_articles          8.0
# avg_tone                                      avg_tone          1.2
# event_type_0                              Make a visit          3.0
# event_type_1                              Host a visit          3.0
# event_type_2                                   Consult          2.0
# event_type_3                                       NaN          NaN
# event_type_4                                       NaN          NaN
# person_0                                  pope francis          8.0
# person_1                                     joe biden          8.0
# person_2                                  kim yong nam          8.0
# person_3                             marco impagliazzo          8.0
# person_4                                           NaN          NaN
# org_0                roman catholic diocese of daejeon          8.0
# org_1                                    united states          8.0
# org_2                          community of santegidio          8.0
# org_3         presidium of the supreme people assembly          8.0
# org_4                        relatedworld food program          8.0
# locs_0                                              IT          8.0
# locs_1                                              VT          8.0
# locs_2                                              US          8.0
# locs_3                                              KS          8.0
# locs_4                                              KN          8.0
# source_0                                       upi.com          8.0
# source_1                                           NaN          NaN
# source_2                                           NaN          NaN
# source_3                                           NaN          NaN
# source_4                                           NaN          NaN
#
#                                       2021-05_id  2021-05_val  \
# nb_events                              nb_events          1.0
# nb_articles                          nb_articles          1.0
# avg_tone                                avg_tone         -6.8
# event_type_0     Use conventional military force          1.0
# event_type_1                                 NaN          NaN
# event_type_2                                 NaN          NaN
# event_type_3                                 NaN          NaN
# event_type_4                                 NaN          NaN
# person_0                           otto warmbier          1.0
# person_1                            kim jong-nam          1.0
# person_2                           fred warmbier          1.0
# person_3                              hong chang          1.0
# person_4                         christopher ahn          1.0
# org_0                   biden justice department          1.0
# org_1         kuala lampur international airport          1.0
# org_2                                   linkedin          1.0
# org_3                         us attorney office          1.0
# org_4                         justice department          1.0
# locs_0                                        MY          1.0
# locs_1                                        IZ          1.0
# locs_2                                        KS          1.0
# locs_3                                        KN          1.0
# locs_4                                        PO          1.0
# source_0                         dailymail.co.uk          1.0
# source_1                                     NaN          NaN
# source_2                                     NaN          NaN
# source_3                                     NaN          NaN
# source_4                                     NaN          NaN
#
#                                             2021-06_id  2021-06_val  \
# nb_events                                    nb_events         11.0
# nb_articles                                nb_articles         13.0
# avg_tone                                      avg_tone          0.9
# event_type_0       Express intent to meet or negotiate          5.0
# event_type_1                              Make a visit          2.0
# event_type_2                              Host a visit          2.0
# event_type_3     Appeal to others to meet or negotiate          1.0
# event_type_4                   Make optimistic comment          1.0
# person_0                                  lee kuan yew          8.0
# person_1                                john o brennan          8.0
# person_2                                 kim dong chul          8.0
# person_3                             paul d ryan r-wis          8.0
# person_4                                 george w bush          8.0
# org_0                                    united states          9.0
# org_1                             u n security council          8.0
# org_2                                          twitter          8.0
# org_3                                      white house          8.0
# org_4         senate minority leader charles e schumer          8.0
# locs_0                                              IT         13.0
# locs_1                                              KN         13.0
# locs_2                                              CH         12.0
# locs_3                                              KS         12.0
# locs_4                                              FR          9.0
# source_0                                    wpjljr.com          8.0
# source_1                                  inquirer.net          2.0
# source_2                               koreaherald.com          2.0
# source_3                              diariodecuba.com          1.0
# source_4                                           NaN          NaN
#
#                                                      2021-07_id  2021-07_val  \
# nb_events                                             nb_events          4.0
# nb_articles                                         nb_articles          4.0
# avg_tone                                               avg_tone          2.2
# event_type_0                                       Host a visit          1.0
# event_type_1                                       Make a visit          1.0
# event_type_2  Express intent to engage in material cooperati...          1.0
# event_type_3                                  Praise or endorse          1.0
# event_type_4                                                NaN          NaN
# person_0                                            shin ji-hye          2.0
# person_1                                           pope francis          2.0
# person_2                                cardinal pietro parolin          2.0
# person_3                                             kim alfred          1.0
# person_4                                              june dprk          1.0
# org_0                                         national assembly          3.0
# org_1                national assembly speaker park byeong-seug          2.0
# org_2                                                   twitter          1.0
# org_3                             national intelligence service          1.0
# org_4                                park national intelligence          1.0
# locs_0                                                       IT          4.0
# locs_1                                                       KN          4.0
# locs_2                                                       KS          4.0
# locs_3                                                       GR          2.0
# locs_4                                                       VM          1.0
# source_0                                        koreaherald.com          2.0
# source_1                                        hankookilbo.com          1.0
# source_2                                              watson.ch          1.0
# source_3                                                    NaN          NaN
# source_4                                                    NaN          NaN
#
#                                        2021-08_id  2021-08_val
# nb_events                               nb_events          2.0
# nb_articles                           nb_articles          3.0
# avg_tone                                 avg_tone          1.1
# event_type_0  Express intent to meet or negotiate          1.0
# event_type_1                         Host a visit          1.0
# event_type_2                                  NaN          NaN
# event_type_3                                  NaN          NaN
# event_type_4                                  NaN          NaN
# person_0                             pope francis          3.0
# person_1                            kwon hee-seog          2.0
# person_2                            alfred xuereb          1.0
# person_3                              pope franci          1.0
# person_4                                joe biden          1.0
# org_0               national intelligence service          1.0
# org_1                               united states          1.0
# org_2                                         NaN          NaN
# org_3                                         NaN          NaN
# org_4                                         NaN          NaN
# locs_0                                         KS          3.0
# locs_1                                         IT          3.0
# locs_2                                         KN          3.0
# locs_3                                         VT          2.0
# locs_4                                         VM          1.0
# source_0                            breitbart.com          2.0
# source_1                         koreatimes.co.kr          1.0
# source_2                                      NaN          NaN
# source_3                                      NaN          NaN
# source_4                                      NaN          NaN
# TOTAL TIME : 0:00:01.152953

# %%
global_df
# Out:
#                                  2021-01_id  2021-01_val  \
# nb_events                         nb_events         12.0
# nb_articles                     nb_articles         66.0
# avg_tone                           avg_tone         -1.3
# event_type_0                         Yield           7.0
# event_type_1                         Reject          2.0
# event_type_2                   Make a visit          1.0
# event_type_3                         Demand          1.0
# event_type_4                   Host a visit          1.0
# person_0                      kim byung-kee         40.0
# person_1                       jon gambrell         21.0
# person_2                          chang sik         19.0
# person_3                      shin beomchul         14.0
# person_4                          joe biden         11.0
# org_0         national intelligence service         57.0
# org_1                          worker party         57.0
# org_2                        united nations         44.0
# org_3                        korean embassy         43.0
# org_4                      associated press         41.0
# locs_0                                   IT         66.0
# locs_1                                   KN         66.0
# locs_2                                   KS         64.0
# locs_3                                   KU         63.0
# locs_4                                   UK         61.0
# source_0                        reuters.com          6.0
# source_1                        asiaone.com          3.0
# source_2                            msn.com          2.0
# source_3                         apnews.com          2.0
# source_4                         tucson.com          1.0
#
#                                             2021-02_id  2021-02_val  \
# nb_events                                    nb_events         19.0
# nb_articles                                nb_articles         21.0
# avg_tone                                      avg_tone         -0.6
# event_type_0                                   Consult         10.0
# event_type_1                              Make a visit          3.0
# event_type_2                            Make statement          2.0
# event_type_3                                    Yield           2.0
# event_type_4           Impose administrative sanctions          1.0
# person_0                                  pope francis         11.0
# person_1                                     joe biden          9.0
# person_2                             marco impagliazzo          9.0
# person_3                                  kim yong nam          9.0
# person_4                                  donald trump          6.0
# org_0                          community of santegidio         11.0
# org_1         presidium of the supreme people assembly          9.0
# org_2                                              cnn          5.0
# org_3                                u s supreme court          2.0
# org_4                              european commission          2.0
# locs_0                                              KN         21.0
# locs_1                                              IT         21.0
# locs_2                                              KS         16.0
# locs_3                                              VM         11.0
# locs_4                                              VT          9.0
# source_0                                       upi.com          9.0
# source_1                              koreatimes.co.kr          4.0
# source_2                                       msn.com          3.0
# source_3                                 oc-breeze.com          2.0
# source_4                               koreaherald.com          1.0
#
#                                     2021-03_id  2021-03_val  \
# nb_events                            nb_events          4.0
# nb_articles                        nb_articles          5.0
# avg_tone                              avg_tone         -2.2
# event_type_0  Abduct, hijack, or take hostage           2.0
# event_type_1    Engage in material cooperation          1.0
# event_type_2   Use conventional military force          1.0
# event_type_3                               NaN          NaN
# event_type_4                               NaN          NaN
# person_0                          leigh scheps          2.0
# person_1                          mario draghi          2.0
# person_2                        suga yoshihide          2.0
# person_3                        richard iacona          1.0
# person_4                                   NaN          NaN
# org_0               army corporal david milano          2.0
# org_1           attorney or of police judicial          1.0
# org_2                        court the freedom          1.0
# org_3                          office of power          1.0
# org_4             union rooms criminal italian          1.0
# locs_0                                      KN          5.0
# locs_1                                      IT          5.0
# locs_2                                      HK          2.0
# locs_3                                      JA          2.0
# locs_4                                      CH          2.0
# source_0                               msn.com          2.0
# source_1                             nhk.or.jp          2.0
# source_2                  ilfattoquotidiano.it          1.0
# source_3                                   NaN          NaN
# source_4                                   NaN          NaN
#
#                                             2021-04_id  2021-04_val  \
# nb_events                                    nb_events          8.0
# nb_articles                                nb_articles          8.0
# avg_tone                                      avg_tone          1.2
# event_type_0                              Make a visit          3.0
# event_type_1                              Host a visit          3.0
# event_type_2                                   Consult          2.0
# event_type_3                                       NaN          NaN
# event_type_4                                       NaN          NaN
# person_0                                  pope francis          8.0
# person_1                                     joe biden          8.0
# person_2                                  kim yong nam          8.0
# person_3                             marco impagliazzo          8.0
# person_4                                           NaN          NaN
# org_0                roman catholic diocese of daejeon          8.0
# org_1                                    united states          8.0
# org_2                          community of santegidio          8.0
# org_3         presidium of the supreme people assembly          8.0
# org_4                        relatedworld food program          8.0
# locs_0                                              IT          8.0
# locs_1                                              VT          8.0
# locs_2                                              US          8.0
# locs_3                                              KS          8.0
# locs_4                                              KN          8.0
# source_0                                       upi.com          8.0
# source_1                                           NaN          NaN
# source_2                                           NaN          NaN
# source_3                                           NaN          NaN
# source_4                                           NaN          NaN
#
#                                       2021-05_id  2021-05_val  \
# nb_events                              nb_events          1.0
# nb_articles                          nb_articles          1.0
# avg_tone                                avg_tone         -6.8
# event_type_0     Use conventional military force          1.0
# event_type_1                                 NaN          NaN
# event_type_2                                 NaN          NaN
# event_type_3                                 NaN          NaN
# event_type_4                                 NaN          NaN
# person_0                           otto warmbier          1.0
# person_1                            kim jong-nam          1.0
# person_2                           fred warmbier          1.0
# person_3                              hong chang          1.0
# person_4                         christopher ahn          1.0
# org_0                   biden justice department          1.0
# org_1         kuala lampur international airport          1.0
# org_2                                   linkedin          1.0
# org_3                         us attorney office          1.0
# org_4                         justice department          1.0
# locs_0                                        MY          1.0
# locs_1                                        IZ          1.0
# locs_2                                        KS          1.0
# locs_3                                        KN          1.0
# locs_4                                        PO          1.0
# source_0                         dailymail.co.uk          1.0
# source_1                                     NaN          NaN
# source_2                                     NaN          NaN
# source_3                                     NaN          NaN
# source_4                                     NaN          NaN
#
#                                             2021-06_id  2021-06_val  \
# nb_events                                    nb_events         11.0
# nb_articles                                nb_articles         13.0
# avg_tone                                      avg_tone          0.9
# event_type_0       Express intent to meet or negotiate          5.0
# event_type_1                              Make a visit          2.0
# event_type_2                              Host a visit          2.0
# event_type_3     Appeal to others to meet or negotiate          1.0
# event_type_4                   Make optimistic comment          1.0
# person_0                                  lee kuan yew          8.0
# person_1                                john o brennan          8.0
# person_2                                 kim dong chul          8.0
# person_3                             paul d ryan r-wis          8.0
# person_4                                 george w bush          8.0
# org_0                                    united states          9.0
# org_1                             u n security council          8.0
# org_2                                          twitter          8.0
# org_3                                      white house          8.0
# org_4         senate minority leader charles e schumer          8.0
# locs_0                                              IT         13.0
# locs_1                                              KN         13.0
# locs_2                                              CH         12.0
# locs_3                                              KS         12.0
# locs_4                                              FR          9.0
# source_0                                    wpjljr.com          8.0
# source_1                                  inquirer.net          2.0
# source_2                               koreaherald.com          2.0
# source_3                              diariodecuba.com          1.0
# source_4                                           NaN          NaN
#
#                                                      2021-07_id  2021-07_val  \
# nb_events                                             nb_events          4.0
# nb_articles                                         nb_articles          4.0
# avg_tone                                               avg_tone          2.2
# event_type_0                                       Host a visit          1.0
# event_type_1                                       Make a visit          1.0
# event_type_2  Express intent to engage in material cooperati...          1.0
# event_type_3                                  Praise or endorse          1.0
# event_type_4                                                NaN          NaN
# person_0                                            shin ji-hye          2.0
# person_1                                           pope francis          2.0
# person_2                                cardinal pietro parolin          2.0
# person_3                                             kim alfred          1.0
# person_4                                              june dprk          1.0
# org_0                                         national assembly          3.0
# org_1                national assembly speaker park byeong-seug          2.0
# org_2                                                   twitter          1.0
# org_3                             national intelligence service          1.0
# org_4                                park national intelligence          1.0
# locs_0                                                       IT          4.0
# locs_1                                                       KN          4.0
# locs_2                                                       KS          4.0
# locs_3                                                       GR          2.0
# locs_4                                                       VM          1.0
# source_0                                        koreaherald.com          2.0
# source_1                                        hankookilbo.com          1.0
# source_2                                              watson.ch          1.0
# source_3                                                    NaN          NaN
# source_4                                                    NaN          NaN
#
#                                        2021-08_id  2021-08_val
# nb_events                               nb_events          2.0
# nb_articles                           nb_articles          3.0
# avg_tone                                 avg_tone          1.1
# event_type_0  Express intent to meet or negotiate          1.0
# event_type_1                         Host a visit          1.0
# event_type_2                                  NaN          NaN
# event_type_3                                  NaN          NaN
# event_type_4                                  NaN          NaN
# person_0                             pope francis          3.0
# person_1                            kwon hee-seog          2.0
# person_2                            alfred xuereb          1.0
# person_3                              pope franci          1.0
# person_4                                joe biden          1.0
# org_0               national intelligence service          1.0
# org_1                               united states          1.0
# org_2                                         NaN          NaN
# org_3                                         NaN          NaN
# org_4                                         NaN          NaN
# locs_0                                         KS          3.0
# locs_1                                         IT          3.0
# locs_2                                         KN          3.0
# locs_3                                         VT          2.0
# locs_4                                         VM          1.0
# source_0                            breitbart.com          2.0
# source_1                         koreatimes.co.kr          1.0
# source_2                                      NaN          NaN
# source_3                                      NaN          NaN
# source_4                                      NaN          NaN
